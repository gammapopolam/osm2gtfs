# %%
from osm_grabber import OSM_Grabber

OSM_Grabber(type='tram', network='Московский транспорт', operator=None, area=102269).fetch(s2s=True, out_dir='D:/capitals_accessibility/ru_mow_osmgrabber')
# Out:
# [out:json][timeout:25];area(3600102269)->.searchArea;nwr["route"=tram]["network"="Московский транспорт"](area.searchArea);out geom;
# 4 448785 Valid counts 1 1 37 37 1 1
# 16 538657 Valid counts 1 1 29 29 1 1
# 17 540033 Valid counts 1 1 24 24 1 1
# 17 540139 Valid counts 1 1 24 24 1 1
# 1 543080 Valid counts 1 1 19 19 1 1
# 13 547827 Valid counts 1 1 21 21 1 1
# 13 556081 Valid counts 1 1 21 21 1 1
# 7 556900 Valid counts 1 1 41 41 1 1
# 11 918052 Valid counts 1 1 38 38 1 1
# 11 920053 Valid counts 1 1 39 39 1 1
# 4 1082824 Valid counts 1 1 38 38 1 1
# 36 1100813 Valid counts 1 1 41 41 1 1
# 36 1100822 Valid counts 1 1 42 42 1 1
# 21 1216232 Valid counts 1 1 9 9 1 1
# 27 1216289 Valid counts 1 1 20 20 1 1
# 27 1216344 Valid counts 1 1 20 20 1 1
# 23 1217244 Valid counts 1 1 19 19 1 1
# 15 1223129 Valid counts 1 1 16 16 1 1
# 23 1223430 Valid counts 1 1 20 20 2 2
# 30 1223431 Valid counts 1 1 27 27 1 1
# 10 1224026 Valid counts 1 1 7 7 1 1
# 10 1224136 Valid counts 1 1 6 6 1 1
# ...
