# %%
from osm_grabber import OSM_Grabber

OSM_Grabber(type='subway', network=None, operator=None, area=102269).fetch(s2s=True, out_dir='D:/capitals_accessibility/ru_mow_osmgrabber')
# Out:
# [out:json][timeout:25];area(3600102269)->.searchArea;nwr["route"=subway](area.searchArea);out geom;
# 5 300607 Valid counts 0 0 13 13 0 0
# 6 300618 Valid counts 1 1 22 22 1 1
# 9 301486 Valid counts 1 1 23 23 1 1
# 4А 302147 Valid counts 1 1 4 4 1 1
# 4 302148 Valid counts 1 1 9 9 1 1
# 3 302149 Valid counts 1 1 20 20 1 1
# 1 305810 Valid counts 1 1 25 25 1 1
# 7 309620 Valid counts 1 1 21 21 1 1
# 10 309623 Valid counts 1 1 24 24 1 1
# 8 326491 Valid counts 1 1 6 6 1 1
# 5 1462011 Valid counts 0 0 13 13 0 0
# 4 1463285 Valid counts 1 1 9 9 1 1
# 4А 1463286 Valid counts 1 1 4 4 1 1
# 3 1472298 Valid counts 1 1 20 20 1 1
# 1 1475755 Valid counts 1 1 25 25 1 1
# 6 1514369 Valid counts 1 1 22 22 1 1
# 7 1516303 Valid counts 1 1 21 21 1 1
# 8 1526350 Valid counts 1 1 6 6 1 1
# 10 1532874 Valid counts 1 1 24 24 1 1
# 9 1570093 Valid counts 1 1 24 24 0 0
# 12 1580607 Valid counts 1 1 5 5 1 1
# 2 2657084 Valid counts 1 1 22 22 1 1
# 2 2657085 Valid counts 1 1 22 22 1 1
# ...
