# %%
from osm_grabber import OSM_Grabber
OSM_Grabber(type='commuter', area=102269).fetch(s2s=True, out_dir='ru_mow_osmgrabber')

# %%
from osm_grabber import OSM_Grabber
OSM_Grabber(type='subway', area=102269).fetch(s2s=True, out_dir='ru_mow_osmgrabber')

# %%
from osm_grabber import OSM_Grabber
OSM_Grabber(type='tram', network='Московский транспорт', operator=None, area=102269).fetch(s2s=True, out_dir='ru_mow_osmgrabber')

# %%
from osm_grabber import OSM_Grabber
OSM_Grabber(type='bus', network='Московский транспорт', operator=None, area=102269).fetch(s2s=True, out_dir='D:/capitals_accessibility/ru_mow_osmgrabber')
# Out:
# [out:json][timeout:25];area(3600102269)->.searchArea;nwr["route"=bus]["network"="Московский транспорт"](area.searchArea);<<;out body geom;
# 201 51087 Valid counts 0 0 15 15 1 1
# 281 53512 Valid counts 0 0 31 31 1 1
# 227 53514 Valid counts 1 1 24 24 0 0
# 605 240309 Valid counts 1 1 27 27 1 1
# 767 286588 Valid counts 1 1 19 19 1 1
# 296 295482 Valid counts 1 1 21 21 1 1
# 343 295485 Valid counts 0 0 29 29 1 1
# 330 295488 Valid counts 1 1 23 23 1 1
# 166 299609 Valid counts 0 0 20 20 1 1
# 32 299610 Valid counts 1 1 25 25 1 1
# 734 299639 Valid counts 1 1 23 23 1 1
# 793 299654 Valid counts 1 1 29 29 0 0
# 720 299662 Valid counts 1 1 11 11 0 0
# 752 299676 Valid counts 0 0 23 23 0 0
# м17 300386 Valid counts 1 1 27 27 1 1
# 911 301604 Valid counts 1 1 14 14 1 1
# 272 301606 Valid counts 1 1 14 14 1 1
# 661 317262 Valid counts 0 0 27 27 1 1
# 696 331423 Valid counts 1 1 25 25 1 1
# 181 331483 Valid counts 1 1 25 25 1 1
# 176 333853 Valid counts 1 1 21 21 1 1
# ...
